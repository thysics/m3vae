# %%
import matplotlib.pylab as plt
import seaborn as sns

# %%
from syndata_v06 import DGP

# %%
synthetic = DGP(lambda_1 = 1.5, lambda_2 = 0.5)
syndata =  synthetic.generate_samples(N = 5000, random_state = 13, p_censor = 0.1)

# %%
colors = sns.color_palette('hls', 3)

# %%
sns.histplot(data = syndata, x = 'durations', hue = 'b', color = colors)
# Out:
# <AxesSubplot:xlabel='durations', ylabel='Count'>

# %%
sns.scatterplot(data = syndata, y = 'durations', x = 'a', hue='b', alpha = 0.5)
# Out:
# <AxesSubplot:xlabel='a', ylabel='durations'>
