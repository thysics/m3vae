# %%
from model.utils_vis import *

# %% [markdown]
# **If z_dim > 2, apply UMAP to visualise the outcome**

# %%
# data_dir = 'golestan/'
data_dir = "syndata_v1/custom/"
model_dir = "z2a07g10"
directory = data_dir + model_dir + "_"

# %%
tmp = present_syn(data_dir, model_dir, directory = directory, durations = 'durations', events = 'events')
# Out:
# Loaded model
# z_dim: 2, alpha: 0.7, beta: 1.0

# %%
tmp.plot_loss()

# %%
tmp.get_latent_vars(metric = 'cosine', n_neighbors = 10)
# Out:
# UMAP has not been applied.

# %%
tmp.present_cluster(dataset = 'test', cls_mean = True)
# Out:
# Clustering data by b
# Means of (synthetic) clusters had been loaded

# %%
tmp.present_figure(figsize = (13, 3.5), z_axis = 0, K = 2, fixed_value = 0.1, N = 5, T = 50, xlim = [0.0, 3.0])
# Out:
# Clustering data by b
# Means of (synthetic) clusters had been loaded

# %%
tmp.show_lat_traversal('test', figsize = (8, 4))

# %%
tmp.show_latent_variations(dataset = 'train')

# %%
tmp.show_latent_space_by_cont(dataset = 'test', column_name = ['a', 'durations'], figsize = (8, 4), with_event = True)
